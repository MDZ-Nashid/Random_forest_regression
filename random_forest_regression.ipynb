# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Random Forest Regression model on the whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor

rfg = RandomForestRegressor(n_estimators=20,random_state=0)

rfg.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=20, random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
rfg.predict([[6.5]])
# Out:
# array([166000.])

# %% [markdown]
# ## Visualising the Random Forest Regression results (higher resolution)

# %%
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape((len(X_grid),1))

plt.scatter(X,y,color='red')
plt.plot(X_grid,rfg.predict(X_grid),color='blue')
plt.title("Salary vs level")
plt.xlabel("level")
plt.ylabel("salary")
plt.show()
# Out:
# <ipython-input-19-3e261023209c>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X),max(X),0.1)
